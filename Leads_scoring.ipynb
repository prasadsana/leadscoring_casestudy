# %%
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

# %%
leads = pd.read_csv('Leads.csv')

# %%
leads.shape
# Out:
# (9240, 37)

# %%
leads.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
leads.describe(include="all")
# Out:
#                                  Prospect ID    Lead Number  \
# count                                   9240    9240.000000
# unique                                  9240            NaN
# top     e70118b9-8fc8-4810-b665-3551a60813ef            NaN
# freq                                       1            NaN
# mean                                     NaN  617188.435606
# std                                      NaN   23405.995698
# min                                      NaN  579533.000000
# 25%                                      NaN  596484.500000
# 50%                                      NaN  615479.000000
# 75%                                      NaN  637387.250000
# max                                      NaN  660737.000000
#
#                     Lead Origin Lead Source Do Not Email Do Not Call  \
# count                      9240        9204         9240        9240
# unique                        5          21            2           2
# ...

# %% [markdown]
# Zero variance - features
# Ordinal data - Label Encoding
# Nominal Data - Onehot Encoder
#
# No use of City and country columns - drop them
# Lead_profile and how did you hear about us culumns - have more "Select" values - drop them

# %% [markdown]
# check for missing values
# check for missing value percentages
# check for columns with "Select" value - drop if necessary
# list down and drop zero variance columns
# drop empty value rows for columns - total visits , specialization
# No use of City and country columns - drop them
#
# Createing dummy variables
#
# pairplot of numeric vaiables : (hue = converted)
#
# Test-train split
#
# modelling
#
# Checking VIF & P-value : re-model
#
# recall - out of actual trues, how many we predicted as true
# precision - out of trues we predicted, hw many are correct
#
# ROC curve

# %%
leads.isnull().sum()
# Out:
# Prospect ID                                         0
# Lead Number                                         0
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# ...
